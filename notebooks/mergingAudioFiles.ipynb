# %%
import librosa
from IPython.display import Audio

x, sr = librosa.load("D:\LUMEN\Dataset\IRMAS_Training_Data\cel\[cel][cla]0001__3.wav")
y, sr = librosa.load("D:\LUMEN\Dataset\IRMAS_Training_Data\cel\[cel][cla]0002__3.wav")
z = 0.5*(x + y)

Audio(data=x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data=z, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Plot the signal read from wav file
plot.subplot(211)
plot.title('2 wav files joined')

plot.plot(x, label="x")
plot.plot(y, label="y")
plot.plot(z, label="joined")
plot.xlabel('Sample')
plot.ylabel('Amplitude')
plot.show()
